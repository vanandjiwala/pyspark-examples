# %% [markdown]
# ## Import Functions

# %%
from pyspark.sql.functions import col, column, concat, lit

# %% [markdown]
# ## Creating a dataframe

# %%
df = spark.read.format("csv").option("header", True).load("/FileStore/tables/Auto-mpg/auto_mpg.csv")

# %% [markdown]
# ## Function documentation

# %%
help(df.withColumn)
# Out:
# Help on method withColumn in module pyspark.sql.dataframe:
#
# withColumn(colName, col) method of pyspark.sql.dataframe.DataFrame instance
#     Returns a new :class:`DataFrame` by adding a column or replacing the
#     existing column that has the same name.
#
#     The column expression must be an expression over this :class:`DataFrame`; attempting to add
#     a column from some other :class:`DataFrame` will raise an error.
#
#     .. versionadded:: 1.3.0
#
#     Parameters
#     ----------
#     colName : str
#         string, name of the new column.
#     col : :class:`Column`
#         a :class:`Column` expression for the new column.
#
#     Notes
#     -----
#     This method introduces a projection internally. Therefore, calling it multiple
#     times, for instance, via loops in order to add multiple columns can generate big
#     plans which can cause performance issues and even `StackOverflowException`.
#     To avoid this, use :func:`select` with the multiple columns at once.
#
#     Examples
#     --------
#     >>> df.withColumn('age2', df.age + 2).collect()
#     [Row(age=2, name='Alice', age2=4), Row(age=5, name='Bob', age2=7)]

# %%
help(df.withColumnRenamed)
# Out:
# Help on method withColumnRenamed in module pyspark.sql.dataframe:
#
# withColumnRenamed(existing, new) method of pyspark.sql.dataframe.DataFrame instance
#     Returns a new :class:`DataFrame` by renaming an existing column.
#     This is a no-op if schema doesn't contain the given column name.
#
#     .. versionadded:: 1.3.0
#
#     Parameters
#     ----------
#     existing : str
#         string, name of the existing column to rename.
#     new : str
#         string, new name of the column.
#
#     Examples
#     --------
#     >>> df.withColumnRenamed('age', 'age2').collect()
#     [Row(age2=2, name='Alice'), Row(age2=5, name='Bob')]

# %%
help(df.toDF)
# Out:
# Help on method toDF in module pyspark.sql.dataframe:
#
# toDF(*cols) method of pyspark.sql.dataframe.DataFrame instance
#     Returns a new :class:`DataFrame` that with new specified column names
#
#     Parameters
#     ----------
#     cols : str
#         new column names
#
#     Examples
#     --------
#     >>> df.toDF('f1', 'f2').collect()
#     [Row(f1=2, f2='Alice'), Row(f1=5, f2='Bob')]

# %% [markdown]
# ## Renaming columns

# %% [markdown]
# ## Select

# %%
#Using alias with select
df.select(df["`car name`"].alias("name")).show()
# Out:
# +--------------------+
# |                name|
# +--------------------+
# |chevrolet chevell...|
# |   buick skylark 320|
# |  plymouth satellite|
# |       amc rebel sst|
# |         ford torino|
# |    ford galaxie 500|
# |    chevrolet impala|
# |   plymouth fury iii|
# |    pontiac catalina|
# |  amc ambassador dpl|
# | dodge challenger se|
# |  plymouth 'cuda 340|
# |chevrolet monte c...|
# |buick estate wago...|
# |toyota corona mar...|
# |     plymouth duster|
# |          amc hornet|
# |       ford maverick|
# |        datsun pl510|
# |volkswagen 1131 d...|
# +--------------------+
# only showing top 20 rows

# %%
#Using alias with select
df.select(col("`car name`").alias("name")).show()
# Out:
# +--------------------+
# |                name|
# +--------------------+
# |chevrolet chevell...|
# |   buick skylark 320|
# |  plymouth satellite|
# |       amc rebel sst|
# |         ford torino|
# |    ford galaxie 500|
# |    chevrolet impala|
# |   plymouth fury iii|
# |    pontiac catalina|
# |  amc ambassador dpl|
# | dodge challenger se|
# |  plymouth 'cuda 340|
# |chevrolet monte c...|
# |buick estate wago...|
# |toyota corona mar...|
# |     plymouth duster|
# |          amc hornet|
# |       ford maverick|
# |        datsun pl510|
# |volkswagen 1131 d...|
# +--------------------+
# only showing top 20 rows

# %%
df.select(concat(col("car name"),lit("-"),col("model year")).alias("car_details")).show() #Using alias with select
# Out:
# +--------------------+
# |         car_details|
# +--------------------+
# |chevrolet chevell...|
# |buick skylark 320-70|
# |plymouth satellit...|
# |    amc rebel sst-70|
# |      ford torino-70|
# | ford galaxie 500-70|
# | chevrolet impala-70|
# |plymouth fury iii-70|
# | pontiac catalina-70|
# |amc ambassador dp...|
# |dodge challenger ...|
# |plymouth 'cuda 34...|
# |chevrolet monte c...|
# |buick estate wago...|
# |toyota corona mar...|
# |  plymouth duster-70|
# |       amc hornet-70|
# |    ford maverick-70|
# |     datsun pl510-70|
# |volkswagen 1131 d...|
# +--------------------+
# only showing top 20 rows

# %%
# Changing multiple column names
df.select(col("mpg").alias("mpg1"),col("car name").alias("name")).show()
# Out:
# +----+--------------------+
# |mpg1|                name|
# +----+--------------------+
# |  18|chevrolet chevell...|
# |  15|   buick skylark 320|
# |  18|  plymouth satellite|
# |  16|       amc rebel sst|
# |  17|         ford torino|
# |  15|    ford galaxie 500|
# |  14|    chevrolet impala|
# |  14|   plymouth fury iii|
# |  14|    pontiac catalina|
# |  15|  amc ambassador dpl|
# |  15| dodge challenger se|
# |  14|  plymouth 'cuda 340|
# |  15|chevrolet monte c...|
# |  14|buick estate wago...|
# |  24|toyota corona mar...|
# |  22|     plymouth duster|
# |  18|          amc hornet|
# |  21|       ford maverick|
# |  27|        datsun pl510|
# |  26|volkswagen 1131 d...|
# +----+--------------------+
# only showing top 20 rows

# %%
df.select(df["mpg"].alias("mpg1"),df["car name"].alias("name")).show()
# Out:
# +----+--------------------+
# |mpg1|                name|
# +----+--------------------+
# |  18|chevrolet chevell...|
# |  15|   buick skylark 320|
# |  18|  plymouth satellite|
# |  16|       amc rebel sst|
# |  17|         ford torino|
# |  15|    ford galaxie 500|
# |  14|    chevrolet impala|
# |  14|   plymouth fury iii|
# |  14|    pontiac catalina|
# |  15|  amc ambassador dpl|
# |  15| dodge challenger se|
# |  14|  plymouth 'cuda 340|
# |  15|chevrolet monte c...|
# |  14|buick estate wago...|
# |  24|toyota corona mar...|
# |  22|     plymouth duster|
# |  18|          amc hornet|
# |  21|       ford maverick|
# |  27|        datsun pl510|
# |  26|volkswagen 1131 d...|
# +----+--------------------+
# only showing top 20 rows

# %% [markdown]
# ## withColumn
# This does not maintain column order

# %%
#withColumn usage. Using select to see the result else entire df will be displayed.
df.withColumn("car_details",concat(col("car name"),lit("-"),col("model year"))).select("car_details").show()
# Out:
# +--------------------+
# |         car_details|
# +--------------------+
# |chevrolet chevell...|
# |buick skylark 320-70|
# |plymouth satellit...|
# |    amc rebel sst-70|
# |      ford torino-70|
# | ford galaxie 500-70|
# | chevrolet impala-70|
# |plymouth fury iii-70|
# | pontiac catalina-70|
# |amc ambassador dp...|
# |dodge challenger ...|
# |plymouth 'cuda 34...|
# |chevrolet monte c...|
# |buick estate wago...|
# |toyota corona mar...|
# |  plymouth duster-70|
# |       amc hornet-70|
# |    ford maverick-70|
# |     datsun pl510-70|
# |volkswagen 1131 d...|
# +--------------------+
# only showing top 20 rows

# %%
# Using withColumn
df.withColumn("year",col("model year")).select("year","car name").show()
# Out:
# +----+--------------------+
# |year|            car name|
# +----+--------------------+
# |  70|chevrolet chevell...|
# |  70|   buick skylark 320|
# |  70|  plymouth satellite|
# |  70|       amc rebel sst|
# |  70|         ford torino|
# |  70|    ford galaxie 500|
# |  70|    chevrolet impala|
# |  70|   plymouth fury iii|
# |  70|    pontiac catalina|
# |  70|  amc ambassador dpl|
# |  70| dodge challenger se|
# |  70|  plymouth 'cuda 340|
# |  70|chevrolet monte c...|
# |  70|buick estate wago...|
# |  70|toyota corona mar...|
# |  70|     plymouth duster|
# |  70|          amc hornet|
# |  70|       ford maverick|
# |  70|        datsun pl510|
# |  70|volkswagen 1131 d...|
# +----+--------------------+
# only showing top 20 rows

# %%
#Expected Error as String is not a valid argument.
df.withColumn("year", "model year")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <command-2111398855956371> in <module>
#       1 #Expected Error as String is not a valid argument.
# ----> 2 df.withColumn("year", "model year")
#
# /databricks/spark/python/pyspark/sql/dataframe.py in withColumn(self, colName, col)
#    2651         """
#    2652         if not isinstance(col, Column):
# -> 2653             raise TypeError("col should be Column")
#    2654         return DataFrame(self._jdf.withColumn(colName, col._jc), self.sql_ctx)
#    2655
#
# TypeError: col should be Column

# %%
df.withColumn("year", df["model year"]).show()
# Out:
# +---+---------+------------+----------+------+------------+----------+------+--------------------+----+
# |mpg|cylinders|displacement|horsepower|weight|acceleration|model year|origin|            car name|year|
# +---+---------+------------+----------+------+------------+----------+------+--------------------+----+
# | 18|        8|         307|       130|  3504|          12|        70|     1|chevrolet chevell...|  70|
# | 15|        8|         350|       165|  3693|        11.5|        70|     1|   buick skylark 320|  70|
# | 18|        8|         318|       150|  3436|          11|        70|     1|  plymouth satellite|  70|
# | 16|        8|         304|       150|  3433|          12|        70|     1|       amc rebel sst|  70|
# | 17|        8|         302|       140|  3449|        10.5|        70|     1|         ford torino|  70|
# | 15|        8|         429|       198|  4341|          10|        70|     1|    ford galaxie 500|  70|
# | 14|        8|         454|       220|  4354|           9|        70|     1|    chevrolet impala|  70|
# | 14|        8|         440|       215|  4312|         8.5|        70|     1|   plymouth fury iii|  70|
# | 14|        8|         455|       225|  4425|          10|        70|     1|    pontiac catalina|  70|
# | 15|        8|         390|       190|  3850|         8.5|        70|     1|  amc ambassador dpl|  70|
# | 15|        8|         383|       170|  3563|          10|        70|     1| dodge challenger se|  70|
# | 14|        8|         340|       160|  3609|           8|        70|     1|  plymouth 'cuda 340|  70|
# | 15|        8|         400|       150|  3761|         9.5|        70|     1|chevrolet monte c...|  70|
# | 14|        8|         455|       225|  3086|          10|        70|     1|buick estate wago...|  70|
# | 24|        4|         113|        95|  2372|          15|        70|     3|toyota corona mar...|  70|
# | 22|        6|         198|        95|  2833|        15.5|        70|     1|     plymouth duster|  70|
# | 18|        6|         199|        97|  2774|        15.5|        70|     1|          amc hornet|  70|
# | 21|        6|         200|        85|  2587|          16|        70|     1|       ford maverick|  70|
# | 27|        4|          97|        88|  2130|        14.5|        70|     3|        datsun pl510|  70|
# | 26|        4|          97|        46|  1835|        20.5|        70|     2|volkswagen 1131 d...|  70|
# +---+---------+------------+----------+------+------------+----------+------+--------------------+----+
# only showing top 20 rows

# %%
#withColumn to perform a transformation on mpg column.
df.withColumn("mpg", col("mpg").cast("int")).withColumn("mpg+2", col("mpg") + 2).select("mpg","mpg+2").show()
# Out:
# +---+-----+
# |mpg|mpg+2|
# +---+-----+
# | 18|   20|
# | 15|   17|
# | 18|   20|
# | 16|   18|
# | 17|   19|
# | 15|   17|
# | 14|   16|
# | 14|   16|
# | 14|   16|
# | 15|   17|
# | 15|   17|
# | 14|   16|
# | 15|   17|
# | 14|   16|
# | 24|   26|
# | 22|   24|
# | 18|   20|
# | 21|   23|
# | 27|   29|
# | 26|   28|
# +---+-----+
# only showing top 20 rows

# %% [markdown]
# ## withColumnRenamed
# This maintains column orders

# %%
df.columns
# Out:
# Out[54]: ['mpg',
#  'cylinders',
#  'displacement',
#  'horsepower',
#  'weight',
#  'acceleration',
#  'model year',
#  'origin',
#  'car name']

# %%
df.withColumnRenamed("mpg", "mpg1").show()
# Out:
# +----+---------+------------+----------+------+------------+----------+------+--------------------+
# |mpg1|cylinders|displacement|horsepower|weight|acceleration|model year|origin|            car name|
# +----+---------+------------+----------+------+------------+----------+------+--------------------+
# |  18|        8|         307|       130|  3504|          12|        70|     1|chevrolet chevell...|
# |  15|        8|         350|       165|  3693|        11.5|        70|     1|   buick skylark 320|
# |  18|        8|         318|       150|  3436|          11|        70|     1|  plymouth satellite|
# |  16|        8|         304|       150|  3433|          12|        70|     1|       amc rebel sst|
# |  17|        8|         302|       140|  3449|        10.5|        70|     1|         ford torino|
# |  15|        8|         429|       198|  4341|          10|        70|     1|    ford galaxie 500|
# |  14|        8|         454|       220|  4354|           9|        70|     1|    chevrolet impala|
# |  14|        8|         440|       215|  4312|         8.5|        70|     1|   plymouth fury iii|
# |  14|        8|         455|       225|  4425|          10|        70|     1|    pontiac catalina|
# |  15|        8|         390|       190|  3850|         8.5|        70|     1|  amc ambassador dpl|
# |  15|        8|         383|       170|  3563|          10|        70|     1| dodge challenger se|
# |  14|        8|         340|       160|  3609|           8|        70|     1|  plymouth 'cuda 340|
# |  15|        8|         400|       150|  3761|         9.5|        70|     1|chevrolet monte c...|
# |  14|        8|         455|       225|  3086|          10|        70|     1|buick estate wago...|
# |  24|        4|         113|        95|  2372|          15|        70|     3|toyota corona mar...|
# |  22|        6|         198|        95|  2833|        15.5|        70|     1|     plymouth duster|
# |  18|        6|         199|        97|  2774|        15.5|        70|     1|          amc hornet|
# |  21|        6|         200|        85|  2587|          16|        70|     1|       ford maverick|
# |  27|        4|          97|        88|  2130|        14.5|        70|     3|        datsun pl510|
# |  26|        4|          97|        46|  1835|        20.5|        70|     2|volkswagen 1131 d...|
# +----+---------+------------+----------+------+------------+----------+------+--------------------+
# only showing top 20 rows

# %%
#Changing multiple column names using chaining withColumnRenamed
df.withColumnRenamed("mpg", "mpg1").withColumnRenamed("car name", "name").show()
# Out:
# +----+---------+------------+----------+------+------------+----------+------+--------------------+
# |mpg1|cylinders|displacement|horsepower|weight|acceleration|model year|origin|                name|
# +----+---------+------------+----------+------+------------+----------+------+--------------------+
# |  18|        8|         307|       130|  3504|          12|        70|     1|chevrolet chevell...|
# |  15|        8|         350|       165|  3693|        11.5|        70|     1|   buick skylark 320|
# |  18|        8|         318|       150|  3436|          11|        70|     1|  plymouth satellite|
# |  16|        8|         304|       150|  3433|          12|        70|     1|       amc rebel sst|
# |  17|        8|         302|       140|  3449|        10.5|        70|     1|         ford torino|
# |  15|        8|         429|       198|  4341|          10|        70|     1|    ford galaxie 500|
# |  14|        8|         454|       220|  4354|           9|        70|     1|    chevrolet impala|
# |  14|        8|         440|       215|  4312|         8.5|        70|     1|   plymouth fury iii|
# |  14|        8|         455|       225|  4425|          10|        70|     1|    pontiac catalina|
# |  15|        8|         390|       190|  3850|         8.5|        70|     1|  amc ambassador dpl|
# |  15|        8|         383|       170|  3563|          10|        70|     1| dodge challenger se|
# |  14|        8|         340|       160|  3609|           8|        70|     1|  plymouth 'cuda 340|
# |  15|        8|         400|       150|  3761|         9.5|        70|     1|chevrolet monte c...|
# |  14|        8|         455|       225|  3086|          10|        70|     1|buick estate wago...|
# |  24|        4|         113|        95|  2372|          15|        70|     3|toyota corona mar...|
# |  22|        6|         198|        95|  2833|        15.5|        70|     1|     plymouth duster|
# |  18|        6|         199|        97|  2774|        15.5|        70|     1|          amc hornet|
# |  21|        6|         200|        85|  2587|          16|        70|     1|       ford maverick|
# |  27|        4|          97|        88|  2130|        14.5|        70|     3|        datsun pl510|
# |  26|        4|          97|        46|  1835|        20.5|        70|     2|volkswagen 1131 d...|
# +----+---------+------------+----------+------+------------+----------+------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ## Changing multiple column names - toDF

# %%
df.select(df.columns).toDF(*["car_mpg","car_cylinders","car_displacement","car_horsepower","car_weight","car_acceleration","car_model year","car_origin","car_name"]).show()
# Out:
# +-------+-------------+----------------+--------------+----------+----------------+--------------+----------+--------------------+
# |car_mpg|car_cylinders|car_displacement|car_horsepower|car_weight|car_acceleration|car_model year|car_origin|            car_name|
# +-------+-------------+----------------+--------------+----------+----------------+--------------+----------+--------------------+
# |     18|            8|             307|           130|      3504|              12|            70|         1|chevrolet chevell...|
# |     15|            8|             350|           165|      3693|            11.5|            70|         1|   buick skylark 320|
# |     18|            8|             318|           150|      3436|              11|            70|         1|  plymouth satellite|
# |     16|            8|             304|           150|      3433|              12|            70|         1|       amc rebel sst|
# |     17|            8|             302|           140|      3449|            10.5|            70|         1|         ford torino|
# |     15|            8|             429|           198|      4341|              10|            70|         1|    ford galaxie 500|
# |     14|            8|             454|           220|      4354|               9|            70|         1|    chevrolet impala|
# |     14|            8|             440|           215|      4312|             8.5|            70|         1|   plymouth fury iii|
# |     14|            8|             455|           225|      4425|              10|            70|         1|    pontiac catalina|
# |     15|            8|             390|           190|      3850|             8.5|            70|         1|  amc ambassador dpl|
# |     15|            8|             383|           170|      3563|              10|            70|         1| dodge challenger se|
# |     14|            8|             340|           160|      3609|               8|            70|         1|  plymouth 'cuda 340|
# |     15|            8|             400|           150|      3761|             9.5|            70|         1|chevrolet monte c...|
# |     14|            8|             455|           225|      3086|              10|            70|         1|buick estate wago...|
# |     24|            4|             113|            95|      2372|              15|            70|         3|toyota corona mar...|
# |     22|            6|             198|            95|      2833|            15.5|            70|         1|     plymouth duster|
# |     18|            6|             199|            97|      2774|            15.5|            70|         1|          amc hornet|
# |     21|            6|             200|            85|      2587|              16|            70|         1|       ford maverick|
# |     27|            4|              97|            88|      2130|            14.5|            70|         3|        datsun pl510|
# |     26|            4|              97|            46|      1835|            20.5|            70|         2|volkswagen 1131 d...|
# +-------+-------------+----------------+--------------+----------+----------------+--------------+----------+--------------------+
# only showing top 20 rows

# %%
# Changing a subset of column names
column_name = ["mpg","cylinders","displacement"]
desired_column_names= ["car_mpg","car_cylinders","car_displacement"]

# %%
df.select(column_name).toDF(*desired_column_names).show()
# Out:
# +-------+-------------+----------------+
# |car_mpg|car_cylinders|car_displacement|
# +-------+-------------+----------------+
# |     18|            8|             307|
# |     15|            8|             350|
# |     18|            8|             318|
# |     16|            8|             304|
# |     17|            8|             302|
# |     15|            8|             429|
# |     14|            8|             454|
# |     14|            8|             440|
# |     14|            8|             455|
# |     15|            8|             390|
# |     15|            8|             383|
# |     14|            8|             340|
# |     15|            8|             400|
# |     14|            8|             455|
# |     24|            4|             113|
# |     22|            6|             198|
# |     18|            6|             199|
# |     21|            6|             200|
# |     27|            4|              97|
# |     26|            4|              97|
# +-------+-------------+----------------+
# only showing top 20 rows
